# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\WIN-MOD\Downloads\active_users_perday.csv')
df
# Out:
#           date  active_users
# 0   2025-03-28            37
# 1   2025-03-29             4
# 2   2025-03-30             2
# 3   2025-03-31             1
# 4   2025-04-01            21
# ..         ...           ...
# 92  2025-07-05             4
# 93  2025-07-06             1
# 94  2025-07-07            21
# 95  2025-07-08            15
# 96  2025-07-09            16
#
# [97 rows x 2 columns]

# %%
plt.plot(df['date'],df['active_users'])

# %%
df=pd.read_csv(r'C:\Users\WIN-MOD\Downloads\avg_docs_uploaded_peruser.csv')
df
# Out:
#           date  avg_docs_uploaded_peruser
# 0   2025-03-28                          2
# 1   2025-03-29                          1
# 2   2025-04-01                          2
# 3   2025-04-02                          1
# 4   2025-04-03                          2
# ..         ...                        ...
# 72  2025-07-04                          3
# 73  2025-07-05                          1
# 74  2025-07-07                          3
# 75  2025-07-08                          1
# 76  2025-07-09                          3
#
# [77 rows x 2 columns]

# %%
plt.plot(df['date'],df['avg_docs_uploaded_peruser'])

# %%
df=pd.read_csv(r'C:\Users\WIN-MOD\Downloads\avg_prompts_peruser.csv')
df
# Out:
#           date  avg_prompts
# 0   2025-03-28            3
# 1   2025-03-29            5
# 2   2025-03-30            2
# 3   2025-03-31            2
# 4   2025-04-01            4
# ..         ...          ...
# 92  2025-07-05            2
# 93  2025-07-06            1
# 94  2025-07-07            3
# 95  2025-07-08            5
# 96  2025-07-09            3
#
# [97 rows x 2 columns]

# %%
plt.plot(df['date'],df['avg_prompts'])

# %%
df=pd.read_csv(r'C:\Users\WIN-MOD\Downloads\total_docs_perday.csv')
df
# Out:
#           date  total_num_of_docs
# 0   2025-03-28                 28
# 1   2025-03-29                  1
# 2   2025-04-01                  4
# 3   2025-04-02                 13
# 4   2025-04-03                  4
# ..         ...                ...
# 72  2025-07-04                 25
# 73  2025-07-05                  3
# 74  2025-07-07                 18
# 75  2025-07-08                  3
# 76  2025-07-09                 15
#
# [77 rows x 2 columns]

# %%
plt.plot(df['date'],df['total_num_of_docs'])

# %%
df=pd.read_csv(r'C:\Users\WIN-MOD\Downloads\total_prompts_perday.csv')
df
# Out:
#           date  total_prompts
# 0   2025-03-28            147
# 1   2025-03-29             22
# 2   2025-03-30              4
# 3   2025-03-31              2
# 4   2025-04-01             99
# ..         ...            ...
# 92  2025-07-05             11
# 93  2025-07-06              1
# 94  2025-07-07             81
# 95  2025-07-08             82
# 96  2025-07-09             52
#
# [97 rows x 2 columns]

# %%
plt.plot(df['date'],df['total_prompts'])
